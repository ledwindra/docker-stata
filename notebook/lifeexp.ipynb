// %%
set more off

// %%
sysuse lifeexp, clear
// Out:
// (Life expectancy, 1998)

// %%
codebook
// Out:
// --------------------------------------------------------------------------------
// region                                                                    Region
// --------------------------------------------------------------------------------
//
//                   type:  numeric (byte)
//                  label:  region
//
//                  range:  [1,3]                        units:  1
//          unique values:  3                        missing .:  0/68
//
//             tabulation:  Freq.   Numeric  Label
//                             44         1  Eur & C.Asia
//                             14         2  N.A.
//                             10         3  S.A.
//
// --------------------------------------------------------------------------------
// country                                                                  Country
// --------------------------------------------------------------------------------
//
//                   type:  string (str28)
//
// ...

// %%
tabulate region
// Out:
//       Region |      Freq.     Percent        Cum.
// -------------+-----------------------------------
// Eur & C.Asia |         44       64.71       64.71
//         N.A. |         14       20.59       85.29
//         S.A. |         10       14.71      100.00
// -------------+-----------------------------------
//        Total |         68      100.00

// %%
regress lexp gnppc
// Out:
//       Source |       SS           df       MS      Number of obs   =        63
// -------------+----------------------------------   F(1, 61)        =     64.98
//        Model |  733.446453         1  733.446453   Prob > F        =    0.0000
//     Residual |  688.490055        61  11.2867222   R-squared       =    0.5158
// -------------+----------------------------------   Adj R-squared   =    0.5079
//        Total |  1421.93651        62  22.9344598   Root MSE        =    3.3596
//
// ------------------------------------------------------------------------------
//         lexp |      Coef.   Std. Err.      t    P>|t|     [95% Conf. Interval]
// -------------+----------------------------------------------------------------
//        gnppc |   .0003234   .0000401     8.06   0.000     .0002432    .0004036
//        _cons |   69.44836   .5479821   126.73   0.000     68.35261    70.54412
// ------------------------------------------------------------------------------

// %%
scatter lexp gnppc
// Out:
// This front-end cannot display the desired image type.
